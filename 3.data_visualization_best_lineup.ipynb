# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')

# %%
# nation_position, club_position, player_positions
df = pd.read_csv('data\players_22.csv', low_memory=False)

# selecting column
df = df[['short_name', 'age', 'nationality_name', 'overall', 'potential',
         'club_name', 'value_eur', 'wage_eur', 'player_positions']]

# selecting only one position
df['player_positions'] = df['player_positions'].str.split(',', expand=True)[0]

# dropping nan
df.dropna(inplace=True)

# %%
players_missing_worldcup = ['K. Benzema', 'S. Mané', 'S. Agüero', 'Sergio Ramos', 'P. Pogba',
                            'M. Reus', 'Diogo Jota', 'A. Harit', 'N. Kanté', 'G. Lo Celso', 'Piqué']

# dropping injured players
drop_index = df[df['short_name'].isin(players_missing_worldcup)].index
df.drop(drop_index, axis=0, inplace=True)

# %%
teams_worldcup = [
    'Qatar', 'Brazil', 'Belgium', 'France', 'Argentina', 'England', 'Spain', 'Portugal',
    'Mexico', 'Netherlands', 'Denmark', 'Germany', 'Uruguay', 'Switzerland', 'United States', 'Croatia',
    'Senegal', 'Iran', 'Japan', 'Morocco', 'Serbia', 'Poland', 'South Korea', 'Tunisia',
    'Cameroon', 'Canada', 'Ecuador', 'Saudi Arabia', 'Ghana', 'Wales', 'Costa Rica', 'Australia'
]

# filtering only national teams in the world cup
df = df[df['nationality_name'].isin(teams_worldcup)]

# %%
# best players
df.sort_values(by=['overall', 'potential', 'value_eur'], ascending=False, inplace=True)

# %% [markdown]
# # Distribution of players overall

# %%
import numpy as np
fig, ax = plt.subplots(figsize=(12, 5), tight_layout=True)

sns.histplot(df, x='overall', binwidth=1)

bins = np.arange(df['overall'].min(), df['overall'].max(), 1)
plt.xticks(bins)
plt.show()

# %% [markdown]
# # Dream Team World Cup Players

# %%
df.drop_duplicates('player_positions')
# viz -> https://trinket.io/python/0813ea96f6
# Out:
#               short_name  age nationality_name  overall  potential  \
# 0               L. Messi   34        Argentina       93         93
# 1         R. Lewandowski   32           Poland       92         92
# 3              Neymar Jr   29           Brazil       91         91
# 4           K. De Bruyne   30          Belgium       91         91
# 8          M. ter Stegen   29          Germany       90         92
# 19            J. Kimmich   26          Germany       89         90
# 15           V. van Dijk   29      Netherlands       89         89
# 28       Bruno Fernandes   26         Portugal       88         89
# 44   T. Alexander-Arnold   22          England       87         92
# 45             J. Sancho   21          England       87         91
# 41             P. Dybala   27        Argentina       87         88
# 64              K. Coman   25           France       86         87
# 50            Jordi Alba   32            Spain       86         86
# 180             Angeliño   24            Spain       83         86
# 379             R. James   21          England       81         86
#
#                club_name    value_eur  wage_eur player_positions
# 0    Paris Saint-Germain   78000000.0  320000.0               RW
# 1      FC Bayern München  119500000.0  270000.0               ST
# 3    Paris Saint-Germain  129000000.0  270000.0               LW
# 4        Manchester City  125500000.0  350000.0               CM
# 8           FC Barcelona   99000000.0  250000.0               GK
# 19     FC Bayern München  108000000.0  160000.0              CDM
# 15             Liverpool   86000000.0  230000.0               CB
# 28     Manchester United  107500000.0  250000.0              CAM
# 44             Liverpool  114000000.0  150000.0               RB
# 45     Manchester United  116500000.0  150000.0               RM
# 41              Juventus   93000000.0  160000.0               CF
# 64     FC Bayern München   81000000.0  120000.0               LM
# 50          FC Barcelona   47000000.0  200000.0               LB
# 180           RB Leipzig   46000000.0   77000.0              LWB
# 379              Chelsea   37000000.0   76000.0              RWB

# %% [markdown]
# # The Most Skillful Players on each National Team

# %%
df_best_players = df.copy()
df_best_players = df_best_players.drop_duplicates('nationality_name').reset_index(drop=True)
country_short =  df_best_players['nationality_name'].str.extract('(^\w{3})', expand=False).str.upper()
df_best_players['name_nationality'] = df_best_players['short_name'] +' (' + country_short + ')'

fig, ax = plt.subplots(figsize=(10, 6), tight_layout=True)

sns.barplot(df_best_players, x='overall', y='name_nationality',
            palette=sns.color_palette('pastel'), width=0.5)
plt.show()
# Out:
# C:\Users\Nandha Kumaran\AppData\Local\Temp\ipykernel_10612\135232182.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(df_best_players, x='overall', y='name_nationality',
# C:\Users\Nandha Kumaran\AppData\Local\Temp\ipykernel_10612\135232182.py:8: UserWarning:
# The palette list has fewer values (10) than needed (30) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(df_best_players, x='overall', y='name_nationality',

# %% [markdown]
# # Best Squad per Team

# %%
def best_squad(nationality):
    df_best_squad = df.copy()
    df_best_squad = df_best_squad.groupby(['nationality_name', 'player_positions']).head(2)
    df_best_squad = df_best_squad[df_best_squad['nationality_name']==nationality].sort_values(['player_positions', 'overall', 'potential'], ascending=False)
    return df_best_squad

# %%
best_squad('Brazil')
# Out:
#             short_name  age nationality_name  overall  potential  \
# 191      Gabriel Jesus   24           Brazil       83         87
# 268        Richarlison   24           Brazil       82         87
# 5069    Paolinho Leima   21           Brazil       70         70
# 8031   Jadenilson Baia   33           Brazil       67         67
# 662             Antony   21           Brazil       79         88
# 656            Rodrygo   20           Brazil       79         88
# 271           Raphinha   24           Brazil       82         87
# 318        Lucas Moura   28           Brazil       81         81
# 311             Danilo   29           Brazil       81         81
# 484    Maikel Catarino   25           Brazil       80         80
# 367       Adryan Zonta   29           Brazil       81         81
# 7248           Vitinho   21           Brazil       68         77
# 3            Neymar Jr   29           Brazil       91         91
# 499       Vinícius Jr.   20           Brazil       80         90
# 465            Everton   25           Brazil       80         83
# 727    Felipe Anderson   28           Brazil       78         78
# 153        Alex Sandro   30           Brazil       83         83
# 245        Alex Telles   28           Brazil       82         82
# 18             Ederson   27           Brazil       89         91
# 20             Alisson   28           Brazil       89         90
# 190             Arthur   24           Brazil       83         85
# 149           Paulinho   32           Brazil       83         83
# 85     Roberto Firmino   29           Brazil       85         85
# 246   Anderson Talisca   27           Brazil       82         83
# 14            Casemiro   29           Brazil       89         89
# 61             Fabinho   27           Brazil       86         88
# 39          Marquinhos   27           Brazil       87         90
# 71        Thiago Silva   36           Brazil       85         85
# 189    Ronaldo Cabrais   29           Brazil       83         83
# 210              Oscar   29           Brazil       82         82
#
#                             club_name    value_eur  wage_eur player_positions
# 191                   Manchester City   52500000.0  150000.0               ST
# 268                           Everton   46500000.0  100000.0               ST
# 5069           Clube Atlético Mineiro    1700000.0   12000.0              RWB
# 8031  Sport Club Corinthians Paulista     525000.0    9000.0              RWB
# 662                              Ajax   39500000.0   17000.0               RW
# 656                    Real Madrid CF   38500000.0  115000.0               RW
# 271                      Leeds United   46000000.0   89000.0               RM
# 318                 Tottenham Hotspur   26000000.0  105000.0               RM
# 311                          Juventus   22500000.0   83000.0               RB
# 484   Sport Club Corinthians Paulista   21000000.0   33000.0               RB
# 367                     RB Bragantino   22500000.0   24000.0              LWB
# 7248                KSV Cercle Brugge    2600000.0    4000.0              LWB
# 3                 Paris Saint-Germain  129000000.0  270000.0               LW
# 499                    Real Madrid CF   46500000.0  120000.0               LW
# 465                        SL Benfica   28000000.0   17000.0               LM
# 727                             Lazio   14000000.0   58000.0               LM
# 153                          Juventus   31500000.0   95000.0               LB
# 245                 Manchester United   27500000.0  130000.0               LB
# 18                    Manchester City   94000000.0  200000.0               GK
# 20                          Liverpool   82000000.0  190000.0               GK
# 190                          Juventus   47000000.0   90000.0               CM
# 149                           Al Ahli   28500000.0   61000.0               CM
# 85                          Liverpool   54000000.0  185000.0               CF
# 246                          Al Nassr   35500000.0   61000.0               CF
# 14                     Real Madrid CF   88000000.0  310000.0              CDM
# 61                          Liverpool   73500000.0  165000.0              CDM
# 39                Paris Saint-Germain   90500000.0  135000.0               CB
# 71                            Chelsea    9500000.0  105000.0               CB
# 189                            Grêmio   35500000.0   49000.0              CAM
# 210                  Shanghai Port FC   30000000.0   38000.0              CAM

# %%
average_overall = [best_squad(team)['overall'].mean() for team in teams_worldcup]

df_average_overall = pd.DataFrame({'Teams': teams_worldcup, 'AVG_Overall': average_overall})
df_average_overall = df_average_overall.dropna()
df_average_overall = df_average_overall.sort_values('AVG_Overall', ascending=False)
df_average_overall
# Out:
#             Teams  AVG_Overall
# 6           Spain    82.400000
# 7        Portugal    81.733333
# 5         England    81.700000
# 1          Brazil    81.666667
# 3          France    81.000000
# 4       Argentina    80.566667
# 11        Germany    80.433333
# 2         Belgium    79.034483
# 9     Netherlands    78.758621
# 8          Mexico    77.727273
# 15        Croatia    76.760000
# 12        Uruguay    76.692308
# 20         Serbia    76.260870
# 19        Morocco    75.920000
# 10        Denmark    75.133333
# 16        Senegal    74.727273
# 13    Switzerland    74.535714
# 18          Japan    73.592593
# 14  United States    73.259259
# 21         Poland    73.111111
# 28          Ghana    72.777778
# 24       Cameroon    72.578947
# 26        Ecuador    71.076923
# 29          Wales    70.821429
# 30     Costa Rica    70.466667
# 31      Australia    70.214286
# 17           Iran    69.705882
# 25         Canada    68.840000
# 23        Tunisia    68.578947
# 27   Saudi Arabia    68.375000

# %%
fig, ax = plt.subplots(figsize=(12, 5), tight_layout=True)

sns.barplot(df_average_overall[:10], x='Teams', y='AVG_Overall',
            palette=sns.color_palette('pastel'))
plt.show()
# Out:
# C:\Users\Nandha Kumaran\AppData\Local\Temp\ipykernel_10612\551090994.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(df_average_overall[:10], x='Teams', y='AVG_Overall',

# %% [markdown]
# # Best Formation for each team

# %%
def best_lineup(nationality, lineup):
    lineup_count = [lineup.count(i) for i in lineup]

    df_lineup = pd.DataFrame({'position': lineup, 'count': lineup_count})
    positions_non_repeated = df_lineup[df_lineup['count'] <= 1]['position'].values
    positions_repeated = df_lineup[df_lineup['count'] > 1]['position'].values

    df_squad = best_squad(nationality)

    df_lineup = pd.concat([
        df_squad[df_squad['player_positions'].isin(positions_non_repeated)].drop_duplicates('player_positions', keep='first'),
        df_squad[df_squad['player_positions'].isin(positions_repeated)]]
    )
    return df_lineup[['short_name', 'overall', 'club_name', 'player_positions']]

# %%
dict_formation = {
    '4-3-3': ['GK', 'RB', 'CB', 'CB', 'LB', 'CDM', 'CM', 'CAM', 'RW', 'ST', 'LW'],
    '4-4-2': ['GK', 'RB', 'CB', 'CB', 'LB', 'RM', 'CM', 'CM', 'LM', 'ST', 'ST'],
    '4-2-3-1': ['GK', 'RB', 'CB', 'CB', 'LB', 'CDM', 'CDM', 'CAM', 'CAM', 'CAM', 'ST'],
}

# %%
for index, row in df_average_overall[:9].iterrows():
    max_average = None
    for key, values in dict_formation.items():
        average = best_lineup(row['Teams'], values)['overall'].mean()
        if max_average is None or average>max_average:
            max_average = average
            formation = key
    print(row['Teams'], formation, max_average)
# Out:
# Spain 4-2-3-1 85.1
# Portugal 4-2-3-1 84.9
# England 4-4-2 84.45454545454545
# Brazil 4-3-3 84.81818181818181
# France 4-2-3-1 83.9
# Argentina 4-3-3 83.54545454545455
# Germany 4-2-3-1 84.1
# Belgium 4-3-3 82.54545454545455
# Netherlands 4-4-2 82.54545454545455

# %%
# best_lineup('Spain', dict_formation['4-2-3-1'])
best_lineup('France', dict_formation['4-3-3'])
# Out:
#        short_name  overall            club_name player_positions
# 6       K. Mbappé       91  Paris Saint-Germain               ST
# 192    O. Dembélé       83         FC Barcelona               RW
# 621     B. Pavard       79    FC Bayern München               RB
# 382      M. Diaby       81  Bayer 04 Leverkusen               LW
# 137  T. Hernández       84             AC Milan               LB
# 31      H. Lloris       87    Tottenham Hotspur               GK
# 377      H. Aouar       81   Olympique Lyonnais               CM
# 229   J. Veretout       82                 Roma              CDM
# 131      N. Fekir       84  Real Betis Balompié              CAM
# 57      R. Varane       86    Manchester United               CB
# 197     J. Koundé       83           Sevilla FC               CB
